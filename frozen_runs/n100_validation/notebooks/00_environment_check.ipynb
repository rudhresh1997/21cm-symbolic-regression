# %%
import sys
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("sklearn:", sklearn.__version__)
# Out:
# Python: 3.11.15 | packaged by conda-forge | (main, Mar  5 2026, 16:59:26) [Clang 19.1.7 ]
# NumPy: 2.4.5
# Pandas: 3.0.3
# sklearn: 1.8.0

# %%
import py21cmfast as p21c
print("21cmFAST imported successfully")
# Out:
# 21cmFAST imported successfully

# %%
from pysr import PySRRegressor
print("PySR imported successfully")
# Out:
# [juliapkg] Found dependencies: /opt/anaconda3/envs/sr21cm/lib/python3.11/site-packages/juliacall/juliapkg.json
# [juliapkg] Found dependencies: /opt/anaconda3/envs/sr21cm/lib/python3.11/site-packages/juliapkg/juliapkg.json
# [juliapkg] Found dependencies: /opt/anaconda3/envs/sr21cm/lib/python3.11/site-packages/pysr/juliapkg.json
# [juliapkg] Locating Julia ^1.10.3
# [juliapkg] Querying Julia versions from https://julialang-s3.julialang.org/bin/versions.json
# [juliapkg] WARNING: About to install Julia 1.12.6 to /opt/anaconda3/envs/sr21cm/julia_env/pyjuliapkg/install.
# [juliapkg]   If you use juliapkg in more than one environment, you are likely to
# [juliapkg]   have Julia installed in multiple locations. It is recommended to
# [juliapkg]   install JuliaUp (https://github.com/JuliaLang/juliaup) or Julia
# [juliapkg]   (https://julialang.org/downloads) yourself.
# [juliapkg] Downloading Julia from https://julialang-s3.julialang.org/bin/mac/aarch64/1.12/julia-1.12.6-macaarch64.dmg
#              downloaded 47.1 MB of 221.5 MB
#              downloaded 91.8 MB of 221.5 MB
#              downloaded 128.8 MB of 221.5 MB
#              downloaded 178.2 MB of 221.5 MB
#              downloaded 217.6 MB of 221.5 MB
#              download complete
# [juliapkg] Verifying download
# [juliapkg] Installing Julia 1.12.6 to /opt/anaconda3/envs/sr21cm/julia_env/pyjuliapkg/install
# [juliapkg] Using Julia 1.12.6 at /opt/anaconda3/envs/sr21cm/julia_env/pyjuliapkg/install/bin/julia
# [juliapkg] Using Julia project at /opt/anaconda3/envs/sr21cm/julia_env
# [juliapkg] Writing Project.toml:
#            | [deps]
#            | PythonCall = "6099a3de-0909-46bc-b1f4-468b9a2dfc0d"
#            | OpenSSL_jll = "458c3c95-2e84-50aa-8efc-19380b2a3a95"
#            | SymbolicRegression = "8254be44-1295-4e6a-a16d-46603ac705cb"
#            | Serialization = "9e88b42a-f829-5b0c-bbe9-9e923198166b"
#            |
#            | [compat]
#            | PythonCall = "=0.9.26"
#            | OpenSSL_jll = "3.0.0 - 3.6"
#            | SymbolicRegression = "~1.11"
#            | Serialization = "^1"
# [juliapkg] Installing packages:
#            | import Pkg
#            | Pkg.Registry.update()
#            | Pkg.add([
#            |   Pkg.PackageSpec(name="PythonCall", uuid="6099a3de-0909-46bc-b1f4-468b9a2dfc0d"),
#            |   Pkg.PackageSpec(name="OpenSSL_jll", uuid="458c3c95-2e84-50aa-8efc-19380b2a3a95"),
#            |   Pkg.PackageSpec(name="SymbolicRegression", uuid="8254be44-1295-4e6a-a16d-46603ac705cb"),
#            |   Pkg.PackageSpec(name="Serialization", uuid="9e88b42a-f829-5b0c-bbe9-9e923198166b"),
#            | ])
#            | Pkg.resolve()
#            | Pkg.precompile()
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Adapt ──────────────────── v4.6.0
#    Installed JLLWrappers ────────────── v1.8.0
#    Installed Parsers ────────────────── v2.8.4
#    Installed ADTypes ────────────────── v1.22.0
#    Installed ArrayInterface ─────────── v7.25.0
#    Installed JSON ───────────────────── v1.6.0
#    Installed FiniteDiff ─────────────── v2.31.0
#    Installed PrecompileTools ────────── v1.3.4
#    Installed StructUtils ────────────── v2.8.2
#    Installed CondaPkg ───────────────── v0.2.36
#    Installed DynamicQuantities ──────── v1.12.3
#    Installed DifferentiationInterface ─ v0.7.18
#     Updating `/opt/anaconda3/envs/sr21cm/julia_env/Project.toml`
# ⌅ [6099a3de] + PythonCall v0.9.26
# ⌅ [8254be44] + SymbolicRegression v1.11.3
#   [9e88b42a] ~ Serialization ⇒ v1.11.0
#   [458c3c95] ~ OpenSSL_jll ⇒ v3.5.4+0
#     Updating `/opt/anaconda3/envs/sr21cm/julia_env/Manifest.toml`
#   [47edcb42] + ADTypes v1.22.0
#   [79e6a3ab] + Adapt v4.6.0
#   [66dad0bd] + AliasTables v1.1.3
#   [4fba245c] + ArrayInterface v7.25.0
#   [d360d2e6] + ChainRulesCore v1.26.1
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [34da2185] + Compat v4.18.1
#   [992eb4ea] + CondaPkg v0.2.36
#   [187b0558] + ConstructionBase v1.6.0
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.19.4
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [a0c0ee7d] + DifferentiationInterface v0.7.18
#   [8d63f2c5] + DispatchDoctor v0.4.28
#   [ffbed154] + DocStringExtensions v0.9.5
# ⌅ [7317a516] + DynamicDiff v0.2.1
# ⌅ [a40a106e] + DynamicExpressions v1.10.4
#   [06fc5a27] + DynamicQuantities v1.12.3
#   [4e289a0a] + EnumX v1.0.7
#   [1a297f60] + FillArrays v1.16.0
#   [6a86dc24] + FiniteDiff v2.31.0
#   [f6369f11] + ForwardDiff v1.3.3
#   [85a1e053] + Interfaces v0.3.2
#   [92d709cd] + IrrationalConstants v0.2.6
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.8.0
#   [682c06a0] + JSON v1.6.0
# ⌃ [d3d80556] + LineSearches v7.5.1
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [30fc2ffe] + LossFunctions v1.2.0
# ⌅ [e80e1ace] + MLJModelInterface v1.11.1
#   [1914dd2f] + MacroTools v0.5.16
#   [0b3b1443] + MicroMamba v0.1.15
#   [e1d29d7a] + Missings v1.2.0
# ⌅ [d41bc354] + NLSolversBase v7.10.0
#   [77ba4419] + NaNMath v1.1.3
# ⌅ [429524aa] + Optim v1.13.3
#   [bac558e1] + OrderedCollections v1.8.1
#   [69de0a69] + Parsers v2.8.4
#   [fa939f87] + Pidfile v1.3.0
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [aea7be01] + PrecompileTools v1.3.4
#   [21216c6a] + Preferences v1.5.2
# ⌅ [92933f4c] + ProgressMeter v1.10.2
#   [43287f4e] + PtrArrays v1.4.0
# ⌅ [6099a3de] + PythonCall v0.9.26
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.1
#   [30f210dd] + ScientificTypesBase v3.1.0
#   [6c6a2e73] + Scratch v1.3.0
#   [efcf1570] + Setfield v1.1.2
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [276daf66] + SpecialFunctions v2.7.2
#   [1e83bf80] + StaticArraysCore v1.4.4
#   [64bff920] + StatisticalTraits v3.5.0
#   [10745b16] + Statistics v1.11.1
#   [82ae8749] + StatsAPI v1.8.0
#   [2913bbd2] + StatsBase v0.34.10
#   [ec057cc2] + StructUtils v2.8.2
# ⌅ [8254be44] + SymbolicRegression v1.11.3
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [1c621080] + TestItems v1.0.0
#   [410a4b4d] + Tricks v0.1.13
#   [e17b2a0c] + UnsafePointers v1.0.0
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
#   [f8abcde7] + micromamba_jll v2.3.1+0
#   [4d7b5844] + pixi_jll v0.41.3+0
#   [0dad84c5] + ArgTools v1.1.2
#   [56f22d72] + Artifacts v1.11.0
#   [2a0f44e3] + Base64 v1.11.0
#   [ade2ca70] + Dates v1.11.0
#   [8ba89e20] + Distributed v1.11.0
#   [f43a241f] + Downloads v1.7.0
#   [7b1f6079] + FileWatching v1.11.0
#   [9fa8497b] + Future v1.11.0
#   [b77e0a4c] + InteractiveUtils v1.11.0
#   [ac6e5ff7] + JuliaSyntaxHighlighting v1.12.0
#   [4af54fe1] + LazyArtifacts v1.11.0
#   [b27032c2] + LibCURL v0.6.4
#   [76f85450] + LibGit2 v1.11.0
#   [8f399da3] + Libdl v1.11.0
#   [37e2e46d] + LinearAlgebra v1.12.0
#   [56ddb016] + Logging v1.11.0
#   [d6f4376e] + Markdown v1.11.0
#   [ca575930] + NetworkOptions v1.3.0
#   [44cfe95a] + Pkg v1.12.1
#   [de0858da] + Printf v1.11.0
#   [3fa0cd96] + REPL v1.11.0
#   [9a3f8284] + Random v1.11.0
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] ~ Serialization ⇒ v1.11.0
#   [6462fe0b] + Sockets v1.11.0
#   [2f01184e] + SparseArrays v1.12.0
#   [f489334b] + StyledStrings v1.11.0
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [8dfed614] + Test v1.11.0
#   [cf7118a7] + UUIDs v1.11.0
#   [4ec0a83e] + Unicode v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.3.0+1
#   [deac9b47] + LibCURL_jll v8.15.0+0
#   [e37daf67] + LibGit2_jll v1.9.0+0
#   [29816b5a] + LibSSH2_jll v1.11.3+1
#   [14a3606d] + MozillaCACerts_jll v2025.11.4
#   [4536629a] + OpenBLAS_jll v0.3.29+0
#   [05823500] + OpenLibm_jll v0.8.7+0
#   [458c3c95] ~ OpenSSL_jll ⇒ v3.5.4+0
#   [bea87d4a] + SuiteSparse_jll v7.8.3+2
#   [83775a58] + Zlib_jll v1.3.1+2
#   [8e850b90] + libblastrampoline_jll v5.15.0+0
#   [8e850ede] + nghttp2_jll v1.64.0+1
#   [3f19e933] + p7zip_jll v17.7.0+0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling packages...
#    1091.2 ms  ✓ ADTypes
#    1089.7 ms  ✓ PrecompileTools
#    1116.4 ms  ✓ Adapt
#    1088.7 ms  ✓ JLLWrappers
#    1357.9 ms  ✓ StructUtils
#     599.0 ms  ✓ ADTypes → ADTypesConstructionBaseExt
#     676.4 ms  ✓ ADTypes → ADTypesChainRulesCoreExt
#    2443.7 ms  ✓ DifferentiationInterface
#    1408.9 ms  ✓ ArrayInterface
#    1894.5 ms  ✓ micromamba_jll
#    5211.1 ms  ✓ Adapt → AdaptSparseArraysExt
#    1116.8 ms  ✓ pixi_jll
#    6934.2 ms  ✓ DynamicQuantities
#    1693.1 ms  ✓ OpenSpecFun_jll
#     881.4 ms  ✓ StructUtils → StructUtilsTablesExt
#     374.3 ms  ✓ StructUtils → StructUtilsStaticArraysCoreExt
#     465.9 ms  ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#     845.4 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#     610.5 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#     552.8 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#     347.9 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#     973.9 ms  ✓ DynamicQuantities → DynamicQuantitiesLinearAlgebraExt
#    1573.6 ms  ✓ MicroMamba
#     571.2 ms  ✓ FiniteDiff
#     578.4 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
#     605.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#   11351.6 ms  ✓ Parsers
#    2763.8 ms  ✓ SpecialFunctions
#    1414.1 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   14171.4 ms  ✓ DynamicExpressions
#    3346.2 ms  ✓ JSON
#    3180.1 ms  ✓ ForwardDiff
#    1419.0 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#    1998.7 ms  ✓ CondaPkg
#    2444.3 ms  ✓ DynamicDiff
#    1428.5 ms  ✓ NLSolversBase
#    1351.5 ms  ✓ LineSearches
#    2631.7 ms  ✓ Optim
#    1074.1 ms  ✓ DynamicExpressions → DynamicExpressionsOptimExt
#   12428.9 ms  ✓ PythonCall
#   47397.8 ms  ✓ SymbolicRegression
#   41 dependencies successfully precompiled in 72 seconds. 90 already precompiled.
#      Project No packages added to or removed from `/opt/anaconda3/envs/sr21cm/julia_env/Project.toml`
#     Manifest No packages added to or removed from `/opt/anaconda3/envs/sr21cm/julia_env/Manifest.toml`
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# PySR imported successfully
